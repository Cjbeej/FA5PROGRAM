# %% [markdown]
# <a href="https://colab.research.google.com/github/Cjbeej/FA5PROGRAM/blob/main/FA5PROGRAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to calculate total price
def calculate_total(price, quantity):
    total = price * quantity
    return total

# Ask user for input
price = float(input("Enter the price of one item: "))
quantity = int(input("Enter the number of items purchased: "))

# Call the function
total_cost = calculate_total(price, quantity)

# Display result
print("Total cost:", total_cost)
# Out:
# Enter the price of one item: 25
# Enter the number of items purchased: 1
# Total cost: 25.0
